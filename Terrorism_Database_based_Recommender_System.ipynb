# %% [markdown]
# #Data Mount

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import warnings
warnings.filterwarnings('ignore')
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Load dataset
path = '/content/drive/MyDrive/Colab Notebooks/terrorismdataset.csv'
df = pd.read_csv(path, encoding='cp1252')

# %% [markdown]
# #Preprocessing

# %%
# Preprocessing
df.fillna(-1, inplace=True)
df = df.loc[:, df.isin([' ', 'NULL', -1]).mean() < .6]
df = df.replace(-1, 'NaN', regex=True)
df.head(5)
# Out:
#         eventid  iyear  imonth  iday  extended  country         country_txt  \
# 0  197000000001   1970       7     2         0       58  Dominican Republic
# 1  197000000002   1970       0     0         0      130              Mexico
# 2  197001000001   1970       1     0         0      160         Philippines
# 3  197001000002   1970       1     0         0       78              Greece
# 4  197001000003   1970       1     0         0      101               Japan
#
#    region                   region_txt provstate  ... property ishostkid  \
# 0       2  Central America & Caribbean       NaN  ...        0       0.0
# 1       1                North America   Federal  ...        0       1.0
# 2       5               Southeast Asia    Tarlac  ...        0       0.0
# 3       8               Western Europe    Attica  ...        1       0.0
# 4       4                    East Asia   Fukouka  ...        1       0.0
#
#   ransom scite1  scite2 dbsource  INT_LOG  INT_IDEO  INT_MISC INT_ANY
# 0    0.0    NaN     NaN     PGIS        0         0         0       0
# 1    1.0    NaN     NaN     PGIS        0         1         1       1
# 2    0.0    NaN     NaN     PGIS       -9        -9         1       1
# 3    0.0    NaN     NaN     PGIS       -9        -9         1       1
# 4    0.0    NaN     NaN     PGIS       -9        -9         1       1
#
# [5 rows x 60 columns]

# %%
# Create documents
documents = []
for index, row in df.iterrows():
    column_strings = [f'{col_name}: {str(value)}' for col_name, value in row.items()]
    document = '\n'.join(column_strings)
    documents.append(document)

docs = []
for index, row in df.iterrows():
    column_values = [str(value) for value in row.values]
    doc = '\n'.join(column_values)
    docs.append(doc)

# %%
# Tokenization using NLTK
import nltk
nltk.download('punkt')
tokenized_documents = [nltk.word_tokenize(doc.lower()) for doc in docs]
d1 = [tuple(doc) for doc in tokenized_documents[:5000]]
d2 = [tuple(doc) for doc in docs[:5000]]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# #Dynamic Reduction

# %%
from sklearn.decomposition import PCA, TruncatedSVD

# Ask the user to choose the dimensionality reduction method (PCA or SVD)
reduction_method = input("Choose the dimensionality reduction method (PCA or SVD): ").upper()

# Apply dimensionality reduction based on user's choice
def apply_dimensionality_reduction(X_tfidf, n_components=100, method='SVD'):
    if method == 'SVD':
        print("Using SVD for dimensionality reduction...")
        reducer = TruncatedSVD(n_components=n_components, random_state=42)
    elif method == 'PCA':
        print("Using PCA for dimensionality reduction...")
        reducer = PCA(n_components=n_components, random_state=42)
    else:
        raise ValueError("Invalid dimensionality reduction method. Choose 'PCA' or 'SVD'.")

    X_reduced = reducer.fit_transform(X_tfidf)
    return X_reduced, reducer

# Validate dimensionality reduction method input
if reduction_method not in ['PCA', 'SVD']:
    print(f"Invalid reduction method. Using default 'SVD'.")
    reduction_method = 'SVD'

# Apply TF-IDF vectorization to `docs`
vectorizer = TfidfVectorizer(max_features=10000, stop_words='english')
X_tfidf = vectorizer.fit_transform(docs)

# Apply the dimensionality reduction method (SVD or PCA)
X_reduced, reducer_model = apply_dimensionality_reduction(X_tfidf, method=reduction_method)


# Display the results (top rows of reduced data)
import pandas as pd
pd.DataFrame(X_reduced).head()
# Out:
# Choose the dimensionality reduction method (PCA or SVD): pca
# Using PCA for dimensionality reduction...
#          0         1         2         3         4         5         6   \
# 0  0.234676  0.024922 -0.059466 -0.045901 -0.026396  0.002460  0.013815
# 1  0.168373 -0.000403 -0.066696 -0.018862 -0.044559 -0.019230  0.000450
# 2  0.311033  0.037130 -0.110636 -0.019274 -0.062646  0.019698  0.046839
# 3  0.313564  0.067764 -0.209717 -0.049678 -0.043022  0.067974  0.028518
# 4  0.361319  0.060528 -0.161732 -0.019361 -0.053653  0.031254  0.052180
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.004375 -0.001367 -0.027643  ... -0.018329  0.013471  0.007686  0.029663
# 1  0.005908  0.054996 -0.027825  ...  0.051030 -0.049493 -0.012488 -0.012784
# 2 -0.021144 -0.015503 -0.011933  ... -0.059537  0.012679  0.036252 -0.030165
# 3 -0.022403 -0.007501 -0.032947  ... -0.020483 -0.027245 -0.015961  0.002216
# 4 -0.000608 -0.017638 -0.071134  ...  0.024259 -0.043019  0.004958  0.038941
#
#          94        95        96        97        98        99
# 0 -0.020292 -0.017085  0.022763 -0.021362 -0.021860  0.009665
# 1  0.002471 -0.015193  0.008046 -0.033380 -0.040444 -0.004213
# 2 -0.041094 -0.025123  0.004143  0.011403  0.041754 -0.029808
# 3 -0.013682  0.005256  0.026570  0.028665 -0.019995 -0.081443
# 4 -0.035209 -0.002933  0.020307  0.024084  0.032951 -0.051013
#
# [5 rows x 100 columns]

# %% [markdown]
# # Dynamic and User Friendly Querying

# %%
# Suggested fix: Ensure proper dimensionality reduction for query and document vectors and verify similarity measure
# Updated function to include checks on the reducer model and query reduction
def recommend_documents(query, docs, X_reduced, vectorizer, reducer_model, top_k=5, measure='cosine'):
    # Preprocess the query to match the documents
    query = preprocess_query(query)

    # Transform the query into TF-IDF space
    query_tfidf = vectorizer.transform([query])

    # Apply the same dimensionality reduction used for the documents
    query_reduced = reducer_model.transform(query_tfidf)

    # Compute similarity using the chosen measure
    similarity_scores = compute_similarity(query_reduced, X_reduced, measure)

    # Get top-k most similar documents based on similarity scores
    top_k_indices = np.argsort(similarity_scores.flatten())[-top_k:][::-1]  # Sort and get top k

    # Retrieve the recommended documents based on top-k indices
    recommended_docs = [docs[i] for i in top_k_indices]

    return recommended_docs, similarity_scores.flatten()[top_k_indices]

# %%
# Function to compute similarity based on the chosen measure
from scipy.stats import pearsonr # import the missing module
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
from sklearn.metrics import jaccard_score as jaccard
from scipy.spatial.distance import cityblock
# Function to compute similarity based on the chosen measure
def compute_similarity(query_vector, doc_vectors, measure='cosine'):
    if measure == 'cosine':
        return cosine_similarity(query_vector, doc_vectors)  # 2D is fine
    elif measure == 'euclidean':
        return euclidean_distances(query_vector, doc_vectors)  # 2D is fine
    elif measure == 'manhattan':
        # Ensure vectors are 1-D before computing cityblock distance
        return np.array([cityblock(query_vector.flatten(), doc_vector.flatten()) for doc_vector in doc_vectors])
    elif measure == 'pearson':
        # Pearson correlation expects 1-D vectors
        return np.array([pearsonr(query_vector.flatten(), doc_vector.flatten())[0] for doc_vector in doc_vectors])
    else:
        raise ValueError(f"Unknown similarity measure: {measure}")

# %%
# Function to display the top-k recommended documents with column names
def display_recommended_documents_with_columns(recommended_docs, scores, df, similarity_measure, top_k=5):
    print(f"\nTop {top_k} documents for query with '{similarity_measure}' similarity:\n")
    for idx, (doc, score) in enumerate(zip(recommended_docs, scores)):
        print(f"\nDocument {idx + 1} (Similarity Score: {score:.4f}):")
        print(f"--- Document content with column names ---")
        # Rebuild the document with column names
        doc_index = df.index[idx]  # Get document index
        doc_with_columns = "\n".join([f"{col_name}: {str(df.iloc[doc_index][col_name])}" for col_name in df.columns])
        print(doc_with_columns[:500])  # Truncate to the first 500 characters for display
        print("------------------------------------------------------------")

# %%
def preprocess_query(query):
    # Lowercase and tokenize the query
    tokenized_query = nltk.word_tokenize(query.lower())
    return ' '.join(tokenized_query)  # Rebuild the query after tokenization for TF-IDF

# %%
# Ask the user for their query and similarity measure
query = input("Enter your search query (e.g., 'Afghanistan terrorism'): ")
similarity_measure = input("Choose the similarity measure (cosine, euclidean, jaccard, manhattan, pearson): ")
# Out:
# Enter your search query (e.g., 'Afghanistan terrorism'): 9/11 bombing
# Choose the similarity measure (cosine, euclidean, jaccard, manhattan, pearson): cosine

# %%
# Validate the similarity measure input
valid_measures = ['cosine', 'euclidean', 'jaccard', 'manhattan', 'pearson']
similarity_measure = input("Choose the similarity measure (cosine, euclidean, jaccard, manhattan, pearson): ")
if similarity_measure not in valid_measures:
    print(f"Invalid similarity measure. Using default 'cosine'.")
    similarity_measure = 'cosine'
# Out:
# Choose the similarity measure (cosine, euclidean, jaccard, manhattan, pearson): cosine

# %%
# Run the recommendation based on the user's input
recommended_docs, scores = recommend_documents(query, docs, X_reduced, vectorizer, reducer_model, top_k=5, measure=similarity_measure)

# Display the recommended documents with the chosen similarity measure
display_recommended_documents_with_columns(recommended_docs, scores, df, similarity_measure)
# Out:
# Top 5 documents for query with 'cosine' similarity:
#
#
# Document 1 (Similarity Score: 0.6294):
# --- Document content with column names ---
# eventid: 197000000001
# iyear: 1970
# imonth: 7
# iday: 2
# extended: 0
# country: 58
# country_txt: Dominican Republic
# region: 2
# region_txt: Central America & Caribbean
# provstate: NaN
# city: Santo Domingo
# latitude: 18.456792
# longitude: -69.951164
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# multiple: 0.0
# success: 1
# suicide: 0
# attacktype1: 1
# attacktype1_txt: Assassination
# targtype1: 14
# targtype1_txt: Private Citizens & Property
# targsubtype1: 68.0
# targsubtype1_txt: Named
# ------------------------------------------------------------
#
# Document 2 (Similarity Score: 0.6032):
# --- Document content with column names ---
# eventid: 197000000002
# iyear: 1970
# imonth: 0
# iday: 0
# extended: 0
# country: 130
# country_txt: Mexico
# region: 1
# region_txt: North America
# provstate: Federal
# city: Mexico city
# latitude: 19.371887
# longitude: -99.086624
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# multiple: 0.0
# success: 1
# suicide: 0
# attacktype1: 6
# attacktype1_txt: Hostage Taking (Kidnapping)
# targtype1: 7
# targtype1_txt: Government (Diplomatic)
# targsubtype1: 45.0
# targsubtype1_txt: Diplomatic Personne
# ------------------------------------------------------------
#
# Document 3 (Similarity Score: 0.6029):
# --- Document content with column names ---
# eventid: 197001000001
# iyear: 1970
# imonth: 1
# iday: 0
# extended: 0
# country: 160
# country_txt: Philippines
# region: 5
# region_txt: Southeast Asia
# provstate: Tarlac
# city: Unknown
# latitude: 15.478598
# longitude: 120.599741
# specificity: 4.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# multiple: 0.0
# success: 1
# suicide: 0
# attacktype1: 1
# attacktype1_txt: Assassination
# targtype1: 10
# targtype1_txt: Journalists & Media
# targsubtype1: 54.0
# targsubtype1_txt: Radio Journalist/Staff/Facility
# cor
# ------------------------------------------------------------
#
# Document 4 (Similarity Score: 0.6017):
# --- Document content with column names ---
# eventid: 197001000002
# iyear: 1970
# imonth: 1
# iday: 0
# extended: 0
# country: 78
# country_txt: Greece
# region: 8
# region_txt: Western Europe
# provstate: Attica
# city: Athens
# latitude: 37.99749
# longitude: 23.762728
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# multiple: 0.0
# success: 1
# suicide: 0
# attacktype1: 3
# attacktype1_txt: Bombing/Explosion
# targtype1: 7
# targtype1_txt: Government (Diplomatic)
# targsubtype1: 46.0
# targsubtype1_txt: Embassy/Consulate
# corp1: NaN
# target1:
# ------------------------------------------------------------
#
# Document 5 (Similarity Score: 0.5958):
# --- Document content with column names ---
# eventid: 197001000003
# iyear: 1970
# imonth: 1
# iday: 0
# extended: 0
# country: 101
# country_txt: Japan
# region: 4
# region_txt: East Asia
# provstate: Fukouka
# city: Fukouka
# latitude: 33.580412
# longitude: 130.396361
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: -9.0
# multiple: 0.0
# success: 1
# suicide: 0
# attacktype1: 7
# attacktype1_txt: Facility/Infrastructure Attack
# targtype1: 7
# targtype1_txt: Government (Diplomatic)
# targsubtype1: 46.0
# targsubtype1_txt: Embassy/Consulate
# corp1:
# ------------------------------------------------------------

# %% [markdown]
# #Most similar Documents in the dataset

# %%
# Define similarity function
def compute_similarity(query_vector, doc_vectors, measure='cosine'):
    if measure == 'cosine':
        return cosine_similarity(query_vector.reshape(1, -1), doc_vectors)
    elif measure == 'euclidean':
        return euclidean_distances(query_vector.reshape(1, -1), doc_vectors)
    elif measure == 'jaccard':
        return np.array([jaccard(query_vector, doc_vector) for doc_vector in doc_vectors])
    elif measure == 'manhattan':
        return np.array([cityblock(query_vector, doc_vector) for doc_vector in doc_vectors])
    elif measure == 'pearson':
        return np.array([pearsonr(query_vector, doc_vector)[0] for doc_vector in doc_vectors])
    else:
        raise ValueError(f'Unknown similarity measure: {measure}')

# %%
# Assuming a query document is available (for now use first document as query)
query_index = 0
query_vector = X_reduced[query_index]

# %%
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
from scipy.spatial.distance import jaccard, cityblock
from scipy.stats import pearsonr

# %%
# Compute similarities for different measures
similarity_measures = ['cosine', 'euclidean', 'jaccard', 'manhattan', 'pearson']
similarity_results = {}
for measure in similarity_measures:
    similarity_results[measure] = compute_similarity(query_vector, X_reduced, measure)

# %%
# Evaluation based on top-k similar documents
def evaluate_similarity(similarity_scores):
    top_k = 5  # Get top 5 results
    top_docs = np.argsort(similarity_scores)[-top_k:]
    return top_docs

# %% [markdown]
# Similar Documents based on each Measure

# %%
# Run evaluation
evaluation_results = {measure: evaluate_similarity(similarity_results[measure]) for measure in similarity_measures}

# Display evaluation results
evaluation_results
# Out:
# {'cosine': array([[157679, 136010, 126699, ...,  63915,  57322,      0]]),
#  'euclidean': array([[     0,  57322,  65075, ..., 115717, 112243, 141171]]),
#  'jaccard': array([ 60566,  60567,  60568,  60592, 181690]),
#  'manhattan': array([115717, 112975,  82045, 112243, 180312]),
#  'pearson': array([65075, 65074, 63915, 57322,     0])}

# %%
# Function to display documents with column names included
def display_recommended_documents_with_columns(evaluation_results, docs, df, top_k=5):
    for measure, indices in evaluation_results.items():
        print(f"\nTop {top_k} documents for similarity measure: {measure}")
        # Ensure indices are flattened to scalar values
        top_docs_indices = indices.flatten()[:top_k]  # Flatten and get top-k documents
        for idx, doc_index in enumerate(top_docs_indices):
            print(f"\nDocument {idx + 1} (Index: {doc_index}):")
            print(f"--- Document content with column names ---")
            # Rebuild the document with column names
            doc_with_columns = "\n".join([f"{col_name}: {str(df.iloc[doc_index][col_name])}" for col_name in df.columns])
            print(doc_with_columns[:500])  # Truncate to the first 500 characters for display
            print("------------------------------------------------------------")

# Assuming `df` is the dataframe containing the original data, and `docs` contains the document strings
display_recommended_documents_with_columns(evaluation_results, docs, df)
# Out:
# Top 5 documents for similarity measure: cosine
#
# Document 1 (Index: 157679):
# --- Document content with column names ---
# eventid: 201601140003
# iyear: 2016
# imonth: 1
# iday: 14
# extended: 0
# country: 93
# country_txt: Indonesia
# region: 5
# region_txt: Southeast Asia
# provstate: Jakarta
# city: Jakarta
# latitude: -6.187549
# longitude: 106.823085
# specificity: 1.0
# vicinity: 0
# summary: 01/14/2016: Two assailants opened fire on a group of people gathered outside an Indonesian National Police (INP) post at Sarinah Mall in Jakarta city, Jakarta province, Indonesia. The crowd had gathered in response to an earlier attack on the post. A
# ------------------------------------------------------------
#
# Document 2 (Index: 136010):
# --- Document content with column names ---
# eventid: 201408030105
# iyear: 2014
# imonth: 8
# iday: 3
# extended: 0
# country: 102
# country_txt: Jordan
# region: 10
# region_txt: Middle East & North Africa
# provstate: Maan
# city: Maan
# latitude: 30.195645
# longitude: 35.733423
# specificity: 1.0
# vicinity: 0
# summary: 08/03/2014: Assailants opened fire on gendarmerie officers guarding a post in Maan city, Maan governorate, Jordan. One officer was killed in the attack. No group claimed responsibility for the incident.
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# mu
# ------------------------------------------------------------
#
# Document 3 (Index: 126699):
# --- Document content with column names ---
# eventid: 201402010007
# iyear: 2014
# imonth: 2
# iday: 1
# extended: 0
# country: 95
# country_txt: Iraq
# region: 10
# region_txt: Middle East & North Africa
# provstate: Babil
# city: Latifiyah
# latitude: 32.982933
# longitude: 44.361595
# specificity: 1.0
# vicinity: 0
# summary: 02/01/2014: A roadside bomb detonated near an army patrol in the Latifiya town, Babil governorate, Iraq. One soldier was killed and two others were wounded in the attack. No group claimed responsibility for the incident.
# crit1: 1
# crit2: 1
# crit3
# ------------------------------------------------------------
#
# Document 4 (Index: 127360):
# --- Document content with column names ---
# eventid: 201402150042
# iyear: 2014
# imonth: 2
# iday: 15
# extended: 0
# country: 95
# country_txt: Iraq
# region: 10
# region_txt: Middle East & North Africa
# provstate: Babil
# city: Jurf al-Sakhar
# latitude: 32.867008
# longitude: 44.220455
# specificity: 1.0
# vicinity: 0
# summary: 02/15/2014: A roadside bomb detonated, targeting a joint Iraqi Army and Iraqi Police Service (IPS) patrol in Jurf Al Sakhar town, Babil governorate, Iraq. This was one of two such attacks on joint patrols in Jurf Al Sakhar on this day. At
# ------------------------------------------------------------
#
# Document 5 (Index: 127361):
# --- Document content with column names ---
# eventid: 201402150043
# iyear: 2014
# imonth: 2
# iday: 15
# extended: 0
# country: 95
# country_txt: Iraq
# region: 10
# region_txt: Middle East & North Africa
# provstate: Babil
# city: Jurf al-Sakhar
# latitude: 32.867008
# longitude: 44.220455
# specificity: 1.0
# vicinity: 0
# summary: 02/15/2014: A roadside bomb detonated, targeting a joint Iraqi Army and Iraqi Police Service (IPS) patrol in Jurf Al Sakhar town, Babil governorate, Iraq. This was one of two such attacks on joint patrols in Jurf Al Sakhar on this day. At
# ------------------------------------------------------------
#
# Top 5 documents for similarity measure: euclidean
#
# Document 1 (Index: 0):
# --- Document content with column names ---
# eventid: 197000000001
# iyear: 1970
# imonth: 7
# iday: 2
# extended: 0
# country: 58
# country_txt: Dominican Republic
# region: 2
# region_txt: Central America & Caribbean
# provstate: NaN
# city: Santo Domingo
# latitude: 18.456792
# longitude: -69.951164
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# multiple: 0.0
# success: 1
# suicide: 0
# attacktype1: 1
# attacktype1_txt: Assassination
# targtype1: 14
# targtype1_txt: Private Citizens & Property
# targsubtype1: 68.0
# targsubtype1_txt: Named
# ------------------------------------------------------------
#
# Document 2 (Index: 57322):
# --- Document content with column names ---
# eventid: 199409210005
# iyear: 1994
# imonth: 9
# iday: 21
# extended: 0
# country: 87
# country_txt: Haiti
# region: 2
# region_txt: Central America & Caribbean
# provstate: Ouest
# city: Port-Au-Prince
# latitude: 18.527716
# longitude: -72.33284
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: -9.0
# multiple: 0.0
# success: 0
# suicide: 0
# attacktype1: 1
# attacktype1_txt: Assassination
# targtype1: 14
# targtype1_txt: Private Citizens & Property
# targsubtype1: 68.0
# targsubtype1_txt: Named Civilian
# ------------------------------------------------------------
#
# Document 3 (Index: 65075):
# --- Document content with column names ---
# eventid: 199704010005
# iyear: 1997
# imonth: 4
# iday: 1
# extended: 0
# country: 156
# country_txt: Panama
# region: 2
# region_txt: Central America & Caribbean
# provstate: Guna Yala
# city: Titina Tiwar
# latitude: 8.750039
# longitude: -77.616676
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# multiple: 1.0
# success: 1
# suicide: 0
# attacktype1: 9
# attacktype1_txt: Unknown
# targtype1: 14
# targtype1_txt: Private Citizens & Property
# targsubtype1: 72.0
# targsubtype1_txt: Farmer
# corp1: NaN
#
# ------------------------------------------------------------
#
# Document 4 (Index: 65074):
# --- Document content with column names ---
# eventid: 199704010004
# iyear: 1997
# imonth: 4
# iday: 1
# extended: 0
# country: 156
# country_txt: Panama
# region: 2
# region_txt: Central America & Caribbean
# provstate: Guna Yala
# city: Titina Tiwar
# latitude: 8.750039
# longitude: -77.616676
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# multiple: 1.0
# success: 1
# suicide: 0
# attacktype1: 9
# attacktype1_txt: Unknown
# targtype1: 14
# targtype1_txt: Private Citizens & Property
# targsubtype1: 72.0
# targsubtype1_txt: Farmer
# corp1: NaN
#
# ------------------------------------------------------------
#
# Document 5 (Index: 55791):
# --- Document content with column names ---
# eventid: 199404020001
# iyear: 1994
# imonth: 4
# iday: 2
# extended: 0
# country: 179
# country_txt: Slovak Republic
# region: 9
# region_txt: Eastern Europe
# provstate: Trnava
# city: Vrbove
# latitude: 48.621279
# longitude: 17.722371
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: -9.0
# multiple: 0.0
# success: 1
# suicide: 0
# attacktype1: 7
# attacktype1_txt: Facility/Infrastructure Attack
# targtype1: 14
# targtype1_txt: Private Citizens & Property
# targsubtype1: 80.0
# targsubtype1_txt: Memoria
# ------------------------------------------------------------
#
# Top 5 documents for similarity measure: jaccard
#
# Document 1 (Index: 60566):
# --- Document content with column names ---
# eventid: 199510030008
# iyear: 1995
# imonth: 10
# iday: 3
# extended: 0
# country: 87
# country_txt: Haiti
# region: 2
# region_txt: Central America & Caribbean
# provstate: Ouest
# city: Port-au-Prince
# latitude: 18.527716
# longitude: -72.33284
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# multiple: 0.0
# success: 1
# suicide: 0
# attacktype1: 1
# attacktype1_txt: Assassination
# targtype1: 4
# targtype1_txt: Military
# targsubtype1: 34.0
# targsubtype1_txt: Military Personnel (soldiers, troop
# ------------------------------------------------------------
#
# Document 2 (Index: 60567):
# --- Document content with column names ---
# eventid: 199510030009
# iyear: 1995
# imonth: 10
# iday: 3
# extended: 0
# country: 118
# country_txt: Macedonia
# region: 9
# region_txt: Eastern Europe
# provstate: Skopje
# city: Skopje
# latitude: 42.000273
# longitude: 21.432541
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# multiple: 0.0
# success: 0
# suicide: 0
# attacktype1: 1
# attacktype1_txt: Assassination
# targtype1: 2
# targtype1_txt: Government (General)
# targsubtype1: 17.0
# targsubtype1_txt: Head of State
# corp1: NaN
# target1: Pres
# ------------------------------------------------------------
#
# Document 3 (Index: 60568):
# --- Document content with column names ---
# eventid: 199510040001
# iyear: 1995
# imonth: 10
# iday: 4
# extended: 0
# country: 153
# country_txt: Pakistan
# region: 6
# region_txt: South Asia
# provstate: Punjab
# city: Lahore
# latitude: 31.50547
# longitude: 74.34288
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# multiple: 0.0
# success: 1
# suicide: 0
# attacktype1: 1
# attacktype1_txt: Assassination
# targtype1: 22
# targtype1_txt: Violent Political Party
# targsubtype1: 109.0
# targsubtype1_txt: Party Official/Candidate/Other Personnel
# ------------------------------------------------------------
#
# Document 4 (Index: 60592):
# --- Document content with column names ---
# eventid: 199510060003
# iyear: 1995
# imonth: 10
# iday: 6
# extended: 0
# country: 153
# country_txt: Pakistan
# region: 6
# region_txt: South Asia
# provstate: Sindh
# city: Karachi
# latitude: 24.891115
# longitude: 67.143311
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# multiple: 0.0
# success: 0
# suicide: 0
# attacktype1: 2
# attacktype1_txt: Armed Assault
# targtype1: 3
# targtype1_txt: Police
# targsubtype1: 23.0
# targsubtype1_txt: Police Patrol (including vehicles and convoys)
# corp1: pol
# ------------------------------------------------------------
#
# Document 5 (Index: 181690):
# --- Document content with column names ---
# eventid: 201712310032
# iyear: 2017
# imonth: 12
# iday: 31
# extended: 0
# country: 160
# country_txt: Philippines
# region: 5
# region_txt: Southeast Asia
# provstate: Maguindanao
# city: Cotabato City
# latitude: 7.209594
# longitude: 124.241966
# specificity: 1.0
# vicinity: 0
# summary: 12/31/2017: An explosive device was discovered and defused at a plaza in Cotabato City, Maguindanao, Philippines. No group claimed responsibility for the incident.
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# multiple: 0.0
# success: 0
# suicid
# ------------------------------------------------------------
#
# Top 5 documents for similarity measure: manhattan
#
# Document 1 (Index: 115717):
# --- Document content with column names ---
# eventid: 201304040007
# iyear: 2013
# imonth: 4
# iday: 4
# extended: 0
# country: 95
# country_txt: Iraq
# region: 10
# region_txt: Middle East & North Africa
# provstate: Kirkuk
# city: Kirkuk
# latitude: 35.45211
# longitude: 44.375465
# specificity: 1.0
# vicinity: 0
# summary: 04/04/2013: An explosive device detonated near a police patrol in Kirkuk city, Kirkuk, Iraq. At least one police officer was injured in the explosion. No group claimed responsibility for the incident.
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# mult
# ------------------------------------------------------------
#
# Document 2 (Index: 112975):
# --- Document content with column names ---
# eventid: 201212130016
# iyear: 2012
# imonth: 12
# iday: 13
# extended: 0
# country: 95
# country_txt: Iraq
# region: 10
# region_txt: Middle East & North Africa
# provstate: Kirkuk
# city: Kirkuk
# latitude: 35.45211
# longitude: 44.375465
# specificity: 1.0
# vicinity: 0
# summary: 12/13/2012: An explosive device detonated targeting a military patrol in Kirkuk city, Kirkuk, Iraq. One soldier was injured and the patrol vehicle was damaged in the blast. No group claimed responsibility for the incident.
# crit1: 1
# crit2: 1
# crit
# ------------------------------------------------------------
#
# Document 3 (Index: 82045):
# --- Document content with column names ---
# eventid: 200612200009
# iyear: 2006
# imonth: 12
# iday: 20
# extended: 0
# country: 95
# country_txt: Iraq
# region: 10
# region_txt: Middle East & North Africa
# provstate: Baghdad
# city: Baghdad
# latitude: 33.303566
# longitude: 44.371773
# specificity: 1.0
# vicinity: 0
# summary: 12/20/2006: A suicide bomber killed 11 and wounded 30 at a checkpoint in the Jadriya area of Baghdad, Iraq.  No claim of responsibility was reported.
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# multiple: 0.0
# success: 1
# suicide: 1
# attacktype1: 3
# ------------------------------------------------------------
#
# Document 4 (Index: 112243):
# --- Document content with column names ---
# eventid: 201211090017
# iyear: 2012
# imonth: 11
# iday: 9
# extended: 0
# country: 95
# country_txt: Iraq
# region: 10
# region_txt: Middle East & North Africa
# provstate: Kirkuk
# city: Kirkuk
# latitude: 35.45211
# longitude: 44.375465
# specificity: 1.0
# vicinity: 1
# summary: 11/09/2012: An explosive device targeting a police patrol detonated south of Kirkuk city, Kirkuk, Iraq. One police officer was injured and a police vehicle was damaged. No group claimed responsibility for the incident.
# crit1: 1
# crit2: 1
# crit3: 1
#
# ------------------------------------------------------------
#
# Document 5 (Index: 180312):
# --- Document content with column names ---
# eventid: 201711080008
# iyear: 2017
# imonth: 11
# iday: 8
# extended: 0
# country: 153
# country_txt: Pakistan
# region: 6
# region_txt: South Asia
# provstate: Balochistan
# city: Isplinji
# latitude: 29.608364
# longitude: 67.051613
# specificity: 1.0
# vicinity: 0
# summary: 11/08/2017: Assailants fired four rockets at Pakistan Armed Forces checkpoint in Isplinji, Balochistan, Pakistan. There were no reported casualties in the attack. No group claimed responsibility for the incident.
# crit1: 1
# crit2: 1
# crit3: 0
# doubtterr:
# ------------------------------------------------------------
#
# Top 5 documents for similarity measure: pearson
#
# Document 1 (Index: 65075):
# --- Document content with column names ---
# eventid: 199704010005
# iyear: 1997
# imonth: 4
# iday: 1
# extended: 0
# country: 156
# country_txt: Panama
# region: 2
# region_txt: Central America & Caribbean
# provstate: Guna Yala
# city: Titina Tiwar
# latitude: 8.750039
# longitude: -77.616676
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# multiple: 1.0
# success: 1
# suicide: 0
# attacktype1: 9
# attacktype1_txt: Unknown
# targtype1: 14
# targtype1_txt: Private Citizens & Property
# targsubtype1: 72.0
# targsubtype1_txt: Farmer
# corp1: NaN
#
# ------------------------------------------------------------
#
# Document 2 (Index: 65074):
# --- Document content with column names ---
# eventid: 199704010004
# iyear: 1997
# imonth: 4
# iday: 1
# extended: 0
# country: 156
# country_txt: Panama
# region: 2
# region_txt: Central America & Caribbean
# provstate: Guna Yala
# city: Titina Tiwar
# latitude: 8.750039
# longitude: -77.616676
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# multiple: 1.0
# success: 1
# suicide: 0
# attacktype1: 9
# attacktype1_txt: Unknown
# targtype1: 14
# targtype1_txt: Private Citizens & Property
# targsubtype1: 72.0
# targsubtype1_txt: Farmer
# corp1: NaN
#
# ------------------------------------------------------------
#
# Document 3 (Index: 63915):
# --- Document content with column names ---
# eventid: 199611100006
# iyear: 1996
# imonth: 11
# iday: 10
# extended: 0
# country: 58
# country_txt: Dominican Republic
# region: 2
# region_txt: Central America & Caribbean
# provstate: National
# city: Santo Domingo
# latitude: 18.456792
# longitude: -69.951164
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: -9.0
# multiple: 0.0
# success: 1
# suicide: 0
# attacktype1: 9
# attacktype1_txt: Unknown
# targtype1: 14
# targtype1_txt: Private Citizens & Property
# targsubtype1: NaN
# targsubtype1_txt: NaN
#
# ------------------------------------------------------------
#
# Document 4 (Index: 57322):
# --- Document content with column names ---
# eventid: 199409210005
# iyear: 1994
# imonth: 9
# iday: 21
# extended: 0
# country: 87
# country_txt: Haiti
# region: 2
# region_txt: Central America & Caribbean
# provstate: Ouest
# city: Port-Au-Prince
# latitude: 18.527716
# longitude: -72.33284
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: -9.0
# multiple: 0.0
# success: 0
# suicide: 0
# attacktype1: 1
# attacktype1_txt: Assassination
# targtype1: 14
# targtype1_txt: Private Citizens & Property
# targsubtype1: 68.0
# targsubtype1_txt: Named Civilian
# ------------------------------------------------------------
#
# Document 5 (Index: 0):
# --- Document content with column names ---
# eventid: 197000000001
# iyear: 1970
# imonth: 7
# iday: 2
# extended: 0
# country: 58
# country_txt: Dominican Republic
# region: 2
# region_txt: Central America & Caribbean
# provstate: NaN
# city: Santo Domingo
# latitude: 18.456792
# longitude: -69.951164
# specificity: 1.0
# vicinity: 0
# summary: NaN
# crit1: 1
# crit2: 1
# crit3: 1
# doubtterr: 0.0
# multiple: 0.0
# success: 1
# suicide: 0
# attacktype1: 1
# attacktype1_txt: Assassination
# targtype1: 14
# targtype1_txt: Private Citizens & Property
# targsubtype1: 68.0
# targsubtype1_txt: Named
# ------------------------------------------------------------

# %% [markdown]
# #Static Querying

# %%
# Recommendation function based on user query
def recommend_documents(query, docs, X_reduced, vectorizer, svd_model, top_k=5, measure='cosine'):
    # Transform query into TF-IDF and SVD-reduced space
    query_tfidf = vectorizer.transform([query])
    query_reduced = svd_model.transform(query_tfidf)

    # Compute similarity
    similarity_scores = compute_similarity(query_reduced, X_reduced, measure)

    # Get top-k most similar documents
    top_k_indices = np.argsort(similarity_scores.flatten())[-top_k:][::-1]  # Sort and get top k

    # Retrieve and display the top-k similar documents
    recommended_docs = [docs[i] for i in top_k_indices]
    return recommended_docs, similarity_scores.flatten()[top_k_indices]

# %%
# Example query: 'Afghanistan terrorism'

query = input('Give me a query you are looking for ')
recommended_docs, scores = recommend_documents(query, docs, X_reduced, vectorizer, svd, top_k=5, measure='cosine')
# Out:
# Give me a query you are looking for 9/11 bombings
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-278213068739> in <cell line: 4>()
#       2
#       3 query = input('Give me a query you are looking for ')
# ----> 4 recommended_docs, scores = recommend_documents(query, docs, X_reduced, vectorizer, svd, top_k=5, measure='cosine')
#
# NameError: name 'svd' is not defined

# %%
# Function to display documents with column names included
def display_recommended_documents_with_columns(evaluation_results, docs, df, top_k=5):
    for measure, indices in evaluation_results.items():
        print(f"\nTop {top_k} documents for similarity measure: {measure}")
        top_docs_indices = indices[:top_k]  # Get top-k documents
        for idx, doc_index in enumerate(top_docs_indices):
            print(f"\nDocument {idx + 1} (Index: {doc_index}):")
            print(f"--- Document content with column names ---")
            # Rebuild the document with column names
            doc_with_columns = "\n".join([f"{col_name}: {str(df.iloc[doc_index][col_name])}" for col_name in df.columns])
            print(doc_with_columns[:500])  # Truncate to the first 500 characters for display
            print("------------------------------------------------------------")

# Assuming `df` is the dataframe containing the original data, and `docs` contains the document strings
display_recommended_documents_with_columns(evaluation_results, docs, df)
